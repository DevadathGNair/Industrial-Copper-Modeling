# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\GUVI\GUVI_Course_New_Batch\Captsone\Industrial_Copper_Modelling\Copper_Set.xlsx - Result 1.csv")
df
# Out:
# <ipython-input-4-3c8daf83922c>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\HP\GUVI\GUVI_Course_New_Batch\Captsone\Industrial_Copper_Modelling\Copper_Set.xlsx - Result 1.csv")
#                                           id   item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
# ...                                      ...         ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0   102.4824216
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0   208.0864686
# ...

# %%
df.isnull().sum()
# Out:
# id                   2
# item_date            1
# quantity tons        0
# customer             1
# country             28
# status               2
# item type            0
# application         24
# thickness            1
# width                0
# material_ref     77919
# product_ref          0
# delivery date        1
# selling_price        1
# dtype: int64

# %%
df[df['id'].isnull()]
# Out:
#          id   item_date quantity tons    customer  country          status  \
# 26      NaN  20210401.0      15.92799  30271717.0     28.0  To be approved
# 104566  NaN  20201113.0     27.096376  30197989.0     27.0             Won
#
#        item type  application  thickness   width        material_ref  \
# 26             W         10.0        0.8  1000.0                 NaN
# 104566         W         59.0        2.8   959.0  HRCL_DD 12 2.8X959
#
#         product_ref  delivery date  selling_price
# 26           611993     20210701.0         1208.0
# 104566       640665     20201201.0          551.0

# %%
df.loc[20:30]
# Out:
#                                       id   item_date quantity tons  \
# 20  F59B65F0-27F8-4BF2-BD25-EBA2B90869E5  20210401.0     71.366978
# 21  A928C0FA-2F58-4322-A706-C4F30EDAE0F9  20210401.0     471.83818
# 22  93B04F7B-0A4C-4D45-AB3A-67DB7888869A  20210401.0     14.203574
# 23  C2D456FC-A66A-4D95-BA1D-3CCEFF49DC2D  20210401.0     53.729746
# 24  03AEAB77-279A-4137-B7E8-F223A56F65B2  20210401.0      79.33399
# 25  0FE5567D-C4FC-4A9E-83DF-AC1E74917C17  20210401.0    179.582796
# 26                                   NaN  20210401.0      15.92799
# 27  D1B675A1-2CCB-4AE0-8507-F6904350FFFB  20210401.0    927.430748
# 28  BEC18863-E965-478B-9861-A49A77F26655  20210401.0     99.059199
# 29  4D3B7D3D-AC31-42D1-95C6-D4D29D9694E9  20210401.0    185.149656
# 30  D8ABD8F4-7A72-446E-8C91-4C9FBF240EF3  20210401.0      9.822404
#
#       customer  country          status item type  application  thickness  \
# 20  30153510.0     30.0             Won         W         41.0      0.595
# ...

# %%
df.loc[104560:104570]
# Out:
#                                           id   item_date quantity tons  \
# 104560  1A4588E2-EA12-44B3-9E87-C6B056E8D038  20201113.0     49.365925
# 104561  C76AB762-B36A-4B8B-85E8-23D5745FB241  20201113.0     68.056618
# 104562  12167C8B-1514-4793-B114-2A0C73353950  20201113.0     53.010984
# 104563  1D10857B-5574-4125-84F7-630D8916D56D  20201113.0     27.270692
# 104564  2A65F589-A1D8-4353-8939-0A17FA3C9E42  20201113.0     50.680733
# 104565  3CD97E41-B14F-49D8-B2A3-5F42F3D0BAA8  20201113.0     60.035449
# 104566                                   NaN  20201113.0     27.096376
# 104567  C567C7EF-E3FD-42E9-8C89-D42955385BBA  20201113.0     28.079467
# 104568  1AB04B5A-A9A8-4B92-9D96-7275089B0F10  20201113.0      44.41677
# 104569  E540EA5A-3B37-451C-B9C8-20E338A4FA6A  20201113.0     23.300096
# 104570  D626E914-558C-4710-975C-237DE71628EF  20201113.0     72.373374
#
#           customer  country status item type  application  thickness   width  \
# ...

# %% [markdown]
# # Data Cleaning and Transformation

# %%
df['customer'].nunique()
# Out:
# 1169

# %%
df['id'].nunique()
# Out:
# 181671

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181671 non-null  object
#  1   item_date      181672 non-null  float64
#  2   quantity tons  181673 non-null  object
#  3   customer       181672 non-null  float64
#  4   country        181645 non-null  float64
#  5   status         181671 non-null  object
#  6   item type      181673 non-null  object
#  7   application    181649 non-null  float64
#  8   thickness      181672 non-null  float64
#  9   width          181673 non-null  float64
#  10  material_ref   103754 non-null  object
#  11  product_ref    181673 non-null  int64
#  12  delivery date  181672 non-null  float64
#  13  selling_price  181672 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 19.4+ MB

# %%
# DataType Conversion
df['item_date'] = pd.to_datetime(df['item_date'], format='%Y%m%d', errors='coerce').dt.date
df['quantity tons'] = pd.to_numeric(df['quantity tons'], errors='coerce')
df['customer'] = pd.to_numeric(df['customer'], errors='coerce')
df['country'] = pd.to_numeric(df['country'], errors='coerce')
df['application'] = pd.to_numeric(df['application'], errors='coerce')
df['thickness'] = pd.to_numeric(df['thickness'], errors='coerce')
df['width'] = pd.to_numeric(df['width'], errors='coerce')
df['material_ref'] = df['material_ref'].str.lstrip('0')
df['product_ref'] = pd.to_numeric(df['product_ref'], errors='coerce')
df['delivery date'] = pd.to_datetime(df['delivery date'], format='%Y%m%d', errors='coerce').dt.date
df['selling_price'] = pd.to_numeric(df['selling_price'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181671 non-null  object
#  1   item_date      181670 non-null  object
#  2   quantity tons  181672 non-null  float64
#  3   customer       181672 non-null  float64
#  4   country        181645 non-null  float64
#  5   status         181671 non-null  object
#  6   item type      181673 non-null  object
#  7   application    181649 non-null  float64
#  8   thickness      181672 non-null  float64
#  9   width          181673 non-null  float64
#  10  material_ref   103754 non-null  object
#  11  product_ref    181673 non-null  int64
#  12  delivery date  181670 non-null  object
#  13  selling_price  181672 non-null  float64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 19.4+ MB

# %%
df.isnull().sum()
# Out:
# id                   2
# item_date            3
# quantity tons        1
# customer             1
# country             28
# status               2
# item type            0
# application         24
# thickness            1
# width                0
# material_ref     77919
# product_ref          0
# delivery date        3
# selling_price        1
# dtype: int64

# %% [markdown]
# ### Handling Null Values

# %%
df['material_ref'].fillna('Not Available',inplace=True)

# %%
df['country'].fillna(method='bfill',inplace=True)

# %%
df.isnull().sum()
# Out:
# id                2
# item_date         3
# quantity tons     1
# customer          1
# country           0
# status            2
# item type         0
# application      24
# thickness         1
# width             0
# material_ref      0
# product_ref       0
# delivery date     3
# selling_price     1
# dtype: int64

# %%
df['application'].unique()
# Out:
# array([10., 41., 28., 59., 15.,  4., 38., 56., 42., 26., 27., 19., 20.,
#        66., 29., 22., 40., 25., 67., 79.,  3., 99.,  2.,  5., 39., 69.,
#        70., 65., 58., 68., nan])

# %%
df['application'].nunique()
# Out:
# 30

# %%
df['application'].fillna(df['application'].mode().iloc[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# id               2
# item_date        3
# quantity tons    1
# customer         1
# country          0
# status           2
# item type        0
# application      0
# thickness        1
# width            0
# material_ref     0
# product_ref      0
# delivery date    3
# selling_price    1
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# id               0
# item_date        0
# quantity tons    0
# customer         0
# country          0
# status           0
# item type        0
# application      0
# thickness        0
# width            0
# material_ref     0
# product_ref      0
# delivery date    0
# selling_price    0
# dtype: int64

# %%
# Creating the copy of DF

ndf = df.copy()

# %%
ndf
# Out:
#                                           id   item_date  quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  2021-04-01      54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  2021-04-01     768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  2021-04-01     386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  2021-04-01     202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  2021-04-01     785.526262
# ...                                      ...         ...            ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  2020-07-02     102.482422
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  2020-07-02     208.086469
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  2020-07-02       4.235594
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8  2020-07-02   -2000.000000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  2020-07-02     406.686538
#
#           customer  country status item type  application  thickness   width  \
# ...

# %% [markdown]
# # EDA

# %%
# Outliers and Skewness
fig, axes = plt.subplots(7, 2, figsize=(10,20))

#quantity tons
sns.boxplot(ax=axes[0, 0], data=ndf['quantity tons'])      
axes[0, 0].set_title('quantity tons - Outliers')
sns.distplot(ax=axes[0, 1], a=ndf['quantity tons'])
axes[0, 1].set_title('quantity tons - Skewness')

#customer
sns.boxplot(ax=axes[1, 0], data=ndf['customer'])          
axes[1, 0].set_title('customer - Outliers')
sns.distplot(ax=axes[1, 1], a=ndf['customer'])
axes[1, 1].set_title('customer - Skewness')

#country
sns.boxplot(ax=axes[2, 0], data=ndf['country'])           
axes[2, 0].set_title('country - Outliers')
sns.distplot(ax=axes[2, 1], a=ndf['country'])
axes[2, 1].set_title('country - Skewness')

#application
sns.boxplot(ax=axes[3, 0], data=ndf['application'])       
axes[3, 0].set_title('application - Outliers')
sns.distplot(ax=axes[3, 1], a=ndf['application'])
axes[3, 1].set_title('application - Skewness')

#thickness
sns.boxplot(ax=axes[4, 0], data=ndf['thickness'])        
axes[4, 0].set_title('thickness - Outliers')
sns.distplot(ax=axes[4, 1], a=ndf['thickness'])
axes[4, 1].set_title('thickness - Skewness')

#width
sns.boxplot(ax=axes[5, 0], data=ndf['width'])            
axes[5, 0].set_title('width - Outliers')
sns.distplot(ax=axes[5, 1], a=ndf['width'])
axes[5, 1].set_title('width - Skewness')

#selling_price
sns.boxplot(ax=axes[6, 0], data=ndf['selling_price'])   
axes[6, 0].set_title('selling_price - Outliers')
sns.distplot(ax=axes[6, 1], a=ndf['selling_price'])
axes[6, 1].set_title('selling_price - Skewness')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Remove the outliers that doesnt make any sense, like values less than zero....

# %%
mask = ndf['selling_price'] <= 0
print(mask.sum())
ndf.loc[mask, 'selling_price'] = np.nan

mask = ndf['quantity tons'] <= 0
print(mask.sum())
ndf.loc[mask, 'quantity tons'] = np.nan

mask1 = ndf['thickness'] <= 0
print(mask1.sum())

mask = ndf['customer'] <= 0
print(mask.sum())

mask = ndf['width'] <= 0
print(mask.sum())
# Out:
# 7
# 4
# 0
# 0
# 0

# %%
ndf.isnull().sum()
# Out:
# id               0
# item_date        0
# quantity tons    4
# customer         0
# country          0
# status           0
# item type        0
# application      0
# thickness        0
# width            0
# material_ref     0
# product_ref      0
# delivery date    0
# selling_price    7
# dtype: int64

# %%
ndf.dropna(inplace=True)

# %%
# Thickness, Quantity tons, selling price are right skewed, so we apply log transformation

# %%
ndf['selling_price_log'] = np.log(ndf['selling_price'])
sns.distplot(ndf['selling_price_log'])
#sns.boxplot(ndf['selling_price_log'])
plt.show()

ndf['thickness_log'] = np.log(ndf['thickness'])
sns.distplot(ndf['thickness_log'])
plt.show()

ndf['quantity_tons_log'] = np.log(ndf['quantity tons'])
sns.distplot(ndf['quantity_tons_log'])
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Correlation

# %%
x=ndf[['quantity_tons_log','application','thickness_log','width','selling_price_log','country','customer','product_ref']].corr()
sns.heatmap(x, annot=True, cmap="viridis")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV

# %%
X=ndf[['quantity_tons_log','status','item type','application','thickness_log','width','country','customer','product_ref']]
y=ndf['selling_price_log']

# %% [markdown]
# ### Encoding categorical values - status, item type

# %%
X_ohe = pd.get_dummies(X[['item type', 'status']], columns=['item type', 'status'], drop_first=True)
X = pd.concat([X[['quantity_tons_log', 'application', 'thickness_log', 'width', 'country', 'customer', 'product_ref']], X_ohe], axis=1)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ### Modeling

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# # All algorithms comparison

# %%
import xgboost
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV

X=ndf[['quantity_tons_log','status','item type','application','thickness_log','width','country','customer','product_ref']]
y=ndf['selling_price_log']

X_ohe = pd.get_dummies(X[['item type', 'status']], columns=['item type', 'status'], drop_first=True)
X = pd.concat([X[['quantity_tons_log', 'application', 'thickness_log', 'width', 'country', 'customer', 'product_ref']], X_ohe], axis=1)

scaler = StandardScaler()
X = scaler.fit_transform(X)

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
models = [DecisionTreeRegressor(),RandomForestRegressor(), GradientBoostingRegressor(), XGBRegressor(), SVR(), KNeighborsRegressor()]
for model in models:
    model.fit(x_train,y_train)
    train_pred = model.predict(x_train)
    test_pred = model.predict(x_test)
    
    train_mse = mean_squared_error(y_train, train_pred)
    train_r2 = r2_score(y_train, train_pred)
    test_mse = mean_squared_error(y_test, test_pred)
    test_r2 = r2_score(y_test, test_pred)
    
    
    print(f"**********{model} Train***********")
    print('Mean squared error:', train_mse)
    print('R-squared:', train_r2)
    
    print(f"**********{model} Test***********")
    print('Mean squared error:', test_mse)
    print('R-squared:', test_r2)
# Out:
# **********DecisionTreeRegressor() Train***********
# Mean squared error: 1.2621296774238926e-34
# R-squared: 1.0
# **********DecisionTreeRegressor() Test***********
# Mean squared error: 0.038771022060734406
# R-squared: 0.8758333628782082
# **********RandomForestRegressor() Train***********
# Mean squared error: 0.0033676494923295516
# R-squared: 0.9895245571018404
# **********RandomForestRegressor() Test***********
# Mean squared error: 0.02392789734352477
# R-squared: 0.9233694035228988
# **********GradientBoostingRegressor() Train***********
# Mean squared error: 0.10033625832236749
# R-squared: 0.6878930699097525
# **********GradientBoostingRegressor() Test***********
# Mean squared error: 0.10000468726368247
# R-squared: 0.6797286980338962
# **********XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
# ...

# %% [markdown]
# ### Best Algorithm from the above evaluation is Random Forest Regressor followed by XGBRegressor

# %% [markdown]
# ### Tuning the Random Forest Regressor Model using Gridsearchcv

# %%
from sklearn.model_selection import GridSearchCV
model = RandomForestRegressor()

parameter_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
}

gridsearch = GridSearchCV(model, parameter_grid, scoring='r2', cv=5)
gridsearch.fit(x_train, y_train)

best_parameters = gridsearch.best_params_

y_pred_hpt_train = gridsearch.predict(x_train)
y_pred_hpt_test = gridsearch.predict(x_test)

train_mse_hpt = mean_squared_error(y_train, y_pred_hpt_train)
train_r2_hpt = r2_score(y_train, y_pred_hpt_train)

test_mse_hpt = mean_squared_error(y_test, y_pred_hpt_test)
test_r2_hpt = r2_score(y_test, y_pred_hpt_test)

print("Best Random Forest Model:")
print(f"Best Hyperparameters: {best_parameters}")
print(f"Final MSE Train: {train_mse_hpt}")
print(f"Final R2 Score Train: {train_r2_hpt}")
print(f"Final MSE Test: {test_mse_hpt}")
print(f"Final R2 Score Test: {test_r2_hpt}")
# Out:
# Best Random Forest Model:
# Best Hyperparameters: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 200}
# Final MSE Train: 0.009305846707354024
# Final R2 Score Train: 0.9710531437360244
# Final MSE Test: 0.02313697973766523
# Final R2 Score Test: 0.9259023669099914

# %% [markdown]
# ### Slight improvement in the model

# %%
best_model = gridsearch.best_estimator_

# %%
best_model
# Out:
# RandomForestRegressor(min_samples_split=10, n_estimators=200)

# %% [markdown]
# # Now Classification

# %%
n2df = ndf[ndf['status'].isin(['Won', 'Lost'])]
n2df
# Out:
#                                           id   item_date  quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  2021-04-01      54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  2021-04-01     768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  2021-04-01     386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  2021-04-01     202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  2021-04-01     785.526262
# ...                                      ...         ...            ...
# 181667  0B812591-B501-4F34-859A-B06381FAEB44  2020-07-02     106.783299
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  2020-07-02     102.482422
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  2020-07-02     208.086469
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  2020-07-02       4.235594
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  2020-07-02     406.686538
#
#           customer  country status item type  application  thickness   width  \
# ...

# %%
X=ndf[['quantity_tons_log','status','item type','application','thickness_log','width','country','customer','product_ref']]
y=ndf['selling_price_log']

X_ohe = pd.get_dummies(X[['item type', 'status']], columns=['item type', 'status'], drop_first=True)
X = pd.concat([X[['quantity_tons_log', 'application', 'thickness_log', 'width', 'country', 'customer', 'product_ref']], X_ohe], axis=1)

scaler = StandardScaler()
X = scaler.fit_transform(X)

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler, OneHotEncoder,LabelBinarizer

X= n2df[['quantity_tons_log','selling_price_log','item type','application','thickness_log','width','country','customer','product_ref']]
Y = n2df['status']

X_ohe = pd.get_dummies(X[['item type']], columns=['item type'], drop_first=True)
X = pd.concat([X[['quantity_tons_log','selling_price_log', 'application', 'thickness_log', 'width', 'country', 'customer', 'product_ref']], X_ohe], axis=1)

be = LabelBinarizer()
be.fit(Y) 
y = be.fit_transform(Y)

scaler = StandardScaler()
X = scaler.fit_transform(X)

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV

models2 = [LogisticRegression(), DecisionTreeClassifier(), RandomForestClassifier(), GradientBoostingClassifier(), XGBClassifier(), SVC(), KNeighborsClassifier()]

for model in models2:
    model.fit(x_train,y_train)
    train_pred = model.predict(x_train)
    test_pred = model.predict(x_test)
    
    accuracy_train = accuracy_score(y_train, train_pred)
    accuracy_test = accuracy_score(y_test, test_pred)
    
    cm_train = confusion_matrix(y_train, train_pred)
    cm_test = confusion_matrix(y_test, test_pred)
    
    print(f"**********{model} Train***********")
    print(f"Train Accuracy: {accuracy_train}")
    print(f"Train Confusion Matrix:\n{cm_train}")
    
    print(f"**********{model} Test***********")
    print(f"Test Accuracy: {accuracy_test}")
    print(f"Test Confusion Matrix:\n{cm_test}")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# **********LogisticRegression() Train***********
# Train Accuracy: 0.7892956857009905
# Train Confusion Matrix:
# [[ 7232 20297]
#  [ 5060 87755]]
# **********LogisticRegression() Test***********
# Test Accuracy: 0.7895768936750092
# Test Confusion Matrix:
# [[ 1812  5094]
#  [ 1237 21944]]
# **********DecisionTreeClassifier() Train***********
# Train Accuracy: 1.0
# Train Confusion Matrix:
# [[27529     0]
#  [    0 92815]]
# **********DecisionTreeClassifier() Test***********
# Test Accuracy: 0.9154119719480174
# Test Confusion Matrix:
# [[ 5654  1252]
#  [ 1293 21888]]
# ...

# %%
### Better Accuracy in Random Forest Classifier

# %% [markdown]
# ### Tuning Random Forest Classifier

# %%
model = RandomForestClassifier()

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
}

grid_search = GridSearchCV(model, param_grid, scoring='accuracy', cv=5)
grid_search.fit(x_train, y_train)

best_parameters = grid_search.best_params_

y_pred_hpt_train = grid_search.predict(x_train)
y_pred_hpt_test = grid_search.predict(x_test)

acc_hpt_train = accuracy_score(y_train, y_pred_hpt_train)
acc_hpt_test = accuracy_score(y_test, y_pred_hpt_test)

print("Best Random Forest Model:")
print(f"Best Hyperparameters: {best_parameters}")
print(f"Final Accuracy Train: {acc_hpt_train}")
print(f"Final Accuracy Test: {acc_hpt_test}")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
best_model_classifier = grid_search.best_estimator_

# %%
best_model_classifier
# Out:
# RandomForestClassifier(n_estimators=200)
